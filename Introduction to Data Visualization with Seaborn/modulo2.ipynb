# %% [markdown]
# # Introduction to Data Visualization with Seaborn
#
# In this chapter, you will create and customize plots that visualize the relationship between two quantitative variables. To do this, you will use scatter plots and line plots to explore how the level of air pollution in a city changes over the course of a day and how horsepower relates to fuel efficiency in cars. You will also see another big advantage of using Seaborn - the ability to easily create subplots in a single figure!
#
# ## Visualizing Two Quantitative Variables

# %% [markdown]
# ### scatterplot() vs. relplot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
student_data = pd.read_csv('../datasets/student-alcohol-consumption.csv')
student_data.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         0  ...     4    1    1      3        6   5   6   6     Urban
# 1         0  ...     3    1    1      3        4   5   5   6     Urban
# 2         3  ...     2    2    3      3       10   7   8  10     Urban
# 3         0  ...     2    1    1      5        2  15  14  15     Urban
# 4         0  ...     2    1    2      5        4   6  10  10     Urban
#
#       study_time
# 0   2 to 5 hours
# 1   2 to 5 hours
# 2   2 to 5 hours
# 3  5 to 10 hours
# 4   2 to 5 hours
#
# ...

# %%
# Change to make subplots based on study time
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter")

# Show plot
plt.show()

# %%
# Change to make subplots based on study time
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter",
           col="study_time")

# Show plot
plt.show()

# %%
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter",
            row="study_time")
plt.show()

# %%
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter")

# Show plot
plt.show()

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"])

# Show plot
plt.show()

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"])

# Show plot
plt.show()

# %% [markdown]
# # Customizing scatter plots

# %%
## Tamanho do ponto

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

mpg =pd.read_csv('../datasets/mpg.csv')

mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Tamanho do ponto

# %%
# tamanho do ponto 
sns.relplot(x="horsepower", y="mpg", data= mpg, size="cylinders")

plt.show()

# %% [markdown]
# ## Pontos coloridos

# %%
# pontos coloridos
# usando hue
sns.relplot(x="horsepower", y="mpg", data= mpg, size="cylinders", hue='cylinders')

plt.show()

# %% [markdown]
# ## Formato do ponto para representar

# %%
# pontos coloridos e formato para representação 
sns.relplot(x="acceleration", y="mpg", data= mpg, hue='origin', style='origin')

plt.show()

# %%
# tranaparencia de ponto
# usaremos alpha 
sns.relplot(x="acceleration", y="mpg", data= mpg, hue='origin', style='origin', alpha=0.4)

plt.show()

# %% [markdown]
# # Tipos de linha

# %% [markdown]
# ## linha

# %%
sns.relplot( data=mpg, x='model_year', y='mpg', kind='line')

plt.show()

# %% [markdown]
# ## Com representação do desvio padão
#
# para isso estamos usando **ci='sd'**

# %%
# Create line plot
sns.relplot( data=mpg, x='model_year', y='mpg', kind='line', ci='sd')

# Show plot
plt.show()
# Out:
# /home/rick/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Sem a formatação 
sns.relplot( data=mpg, x='model_year', y='mpg', kind='line', ci=None)

# Show plot
plt.show()
# Out:
# /home/rick/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ## Dashes

# %%
# dashes False
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin", dashes=False)

# Show plot
plt.show()
# Out:
# /home/rick/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Dashes True
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin", dashes=True)

# Show plot
plt.show()
# Out:
# /home/rick/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ## Markers

# %%
# Add markers and make each line have the same style
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin", dashes=False, markers=True)

# Show plot
plt.show()
# Out:
# /home/rick/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
