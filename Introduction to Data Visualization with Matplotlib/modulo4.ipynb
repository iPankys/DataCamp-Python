# %% [markdown]
# # Introduction to Data Visualization with Matplotlib
# ## Preparing your figures to share with others
#
# 100%

# %%
import matplotlib.pyplot as plt
import pandas as pd

df =  pd.read_csv('../datasets/seattle_weather.csv')
seattle_weather = df[:12] # so queremos trabalhar com dado de um ano
seattle_weather['MONTH'] = seattle_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))

# fazendo analogo 
df =  pd.read_csv('../datasets/austin_weather.csv')
austin_weather = df[:12] # so queremos trabalhar com dado de um ano
austin_weather['MONTH'] = austin_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))
# Out:
# /tmp/ipykernel_31578/232679062.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattle_weather['MONTH'] = seattle_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))
# /tmp/ipykernel_31578/232679062.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   austin_weather['MONTH'] = austin_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))

# %% [markdown]
# ## Estilo de grafico
#
# Vamos usar **plt.style.use**  repare varios grafico abaixo para ver a diferença
#
# Link para saber mais estilo [https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)

# %%
plt.style.use("seaborn-colorblind")
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")
plt.show()

# %%
plt.style.use("bmh")
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")
plt.show()

# %%
plt.style.use("ggplot")
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")
plt.show()

# %%
plt.style.use("default")
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")
plt.show()

# %% [markdown]
# ## Salvando imagem
#
#
#
# - Qualidade: fig.savefig("gold_medals.jpg", quality=50)
#
# - Resolução: fig.savefig("gold_medals.png", dpi=300)
#
# - Formato Svg: fig.savefig("gold_medals.svg")
#
# - tamanho: fig.set_size_inches([5, 3])

# %%
plt.style.use("ggplot")
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")

fig.savefig("salvando.png") # Salvando imagem

plt.show()

# %% [markdown]
# ## Tamanho

# %%
plt.style.use("ggplot")
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")

fig.set_size_inches([5, 3]) # tamanho

plt.show()

# %% [markdown]
# # Automação
#
# Aqui esta como sento, tipo nos não precisamos colocar o nome do esporte e criar para cada coluna, estamos automatizando nesse sentindo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
summer_2016_medals = pd.read_csv('../datasets/summer2016.csv')

# %%
sports = summer_2016_medals["Sport"].unique()
print(sports)
# Out:
# ['Rowing' 'Taekwondo' 'Handball' 'Wrestling' 'Gymnastics' 'Swimming'
#  'Basketball' 'Boxing' 'Volleyball' 'Athletics' 'Rugby Sevens' 'Judo'
#  'Rhythmic Gymnastics' 'Weightlifting' 'Equestrianism' 'Badminton'
#  'Water Polo' 'Football' 'Fencing' 'Shooting' 'Sailing' 'Beach Volleyball'
#  'Canoeing' 'Hockey' 'Cycling' 'Tennis' 'Diving' 'Table Tennis'
#  'Triathlon' 'Archery' 'Synchronized Swimming' 'Modern Pentathlon'
#  'Trampolining' 'Golf']

# %%
fig, ax = plt.subplots()
for sport in sports:
    sport_df = summer_2016_medals[summer_2016_medals["Sport"] == sport]
    ax.bar(sport, sport_df["Height"].mean(),
    yerr=sport_df["Height"].std())
    

ax.set_ylabel("Height (cm)")
ax.set_xticklabels(sports, rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_31578/3735769114.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sports, rotation=90)
