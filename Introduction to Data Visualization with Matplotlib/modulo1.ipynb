# %% [markdown]
# # Introduction to Data Visualization with
# ## Introduction to Matplotlib
# 100#

# %%
import matplotlib.pyplot as plt
import pandas as pd
import calendar

# %%
df =  pd.read_csv('../datasets/seattle_weather.csv')

# %%
df.head()
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
#
#    MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0          -7777.0              0.0              0.0              0.0
# 1          -7777.0          -7777.0              0.0              0.0
# 2              1.0          -7777.0          -7777.0              0.0
# 3             12.0              7.0              3.0          -7777.0
# 4             56.0             38.0             19.0              1.0
#
#    MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  \
# ...

# %%
seattle_weather = df[:12] # so queremos trabalhar com dado de um ano
seattle_weather.shape
# Out:
# (12, 80)

# %%
# DATE e do tipo inteiro que representa o mes, vamo criar uma coluna do tipo mes 
seattle_weather['MONTH'] = seattle_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))
seattle_weather['MONTH']
# Out:
# /tmp/ipykernel_28258/2934410077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattle_weather['MONTH'] = seattle_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))
# 0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# 5     Jun
# 6     Jul
# 7     Aug
# 8     Sep
# 9     Oct
# 10    Nov
# 11    Dec
# Name: MONTH, dtype: object

# %%
# fazendo analogo 
df =  pd.read_csv('../datasets/austin_weather.csv')
austin_weather = df[:12] # so queremos trabalhar com dado de um ano
austin_weather['MONTH'] = austin_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))
# Out:
# /tmp/ipykernel_28258/2684556232.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   austin_weather['MONTH'] = austin_weather['DATE'].apply(lambda x: pd.Timestamp(month=x, day=1, year=2000).strftime('%b'))

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %% [markdown]
# ## Adding markers

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"], marker="o")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],
seattle_weather["MLY-TAVG-NORMAL"],
marker="v")
plt.show()

# %% [markdown]
# ### Link com mais formados
# [Outrod formados](https://matplotlib.org/stable/api/markers_api.html)

# %% [markdown]
# ## Estilo de linhas

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],
seattle_weather["MLY-TAVG-NORMAL"],
marker="v", linestyle="--")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],
seattle_weather["MLY-TAVG-NORMAL"],
marker="v", linestyle="None")
plt.show()

# %% [markdown]
# ## Cor da linha

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],
seattle_weather["MLY-TAVG-NORMAL"],
marker="v", linestyle="--", color="r")
plt.show()

# %% [markdown]
# ## Nomes do eixo e titutlo

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"],
seattle_weather["MLY-TAVG-NORMAL"],
marker="v", linestyle="--", color="r")

ax.set_xlabel("Time (months)")
ax.set_ylabel("Average temperature (Fahrenheit degrees)")
ax.set_title("Weather in Seattle")

plt.show()

# %% [markdown]
# # Small multiples
#
# No proximo exemplo, o grafico esta confuso pois existe varios grafico juntos, a ideia é fazer varias telas para organizar melhor

# %%
fig, ax = plt.subplots()
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
color='r')
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"],
linestyle='--', color='r')
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"],
linestyle='--', color='r')
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"],
linestyle='--', color='b')
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"],
linestyle='--', color='b')
plt.show()

# %%
# 3 linha e duda coluna de tela
fig, ax = plt.subplots(3, 2)
plt.show()

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"],
color='b')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"],
linestyle='--', color='b')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"],
linestyle='--', color='b')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
color='r')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"],
linestyle='--', color='r')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"],
linestyle='--', color='r')
ax[0].set_ylabel("Precipitation (inches)")
ax[1].set_ylabel("Precipitation (inches)")
ax[1].set_xlabel("Time (months)")
plt.show()

# %% [markdown]
# **Obs1:**  quando estamos lidando com uma coluna podemos usar como exemplo de cima, mas for mais remos que usar a notação "az[1,3]"  por exemplo
#
# **OBS2:** Repare que a coluna y esta de forma independente
#
# ## Deixando o eixo y com o mesmo tamanho

# %%
# repare nesse grafico e do anterior principalemnte em relação ao eixo y
# quem faz toda essa magia é sharey=True
# da linha fig, ax = plt.subplots(2, 1, sharey=True)
fig, ax = plt.subplots(2, 1, sharey=True)

ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"],
color='b')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"],
linestyle='--', color='b')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"],
linestyle='--', color='b')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
color='r')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"],
linestyle='--', color='r')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"],
linestyle='--', color='r')
ax[0].set_ylabel("Precipitation (inches)")
ax[1].set_ylabel("Precipitation (inches)")
ax[1].set_xlabel("Time (months)")
plt.show()
